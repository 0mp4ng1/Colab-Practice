# %% [markdown]
# <a href="https://colab.research.google.com/github/0mpang1/Colab-Practice/blob/master/Lec7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diabets Logistic

# %%
from torch import nn, optim, from_numpy
import numpy as np

xy = np.loadtxt('/content/sample_data/diabetes.csv.gz', delimiter=',', dtype=np.float32)
x_data = from_numpy(xy[:, 0:-1])
y_data = from_numpy(xy[:, [-1]])
print(f'X\'s shape: {x_data.shape} | Y\'s shape: {y_data.shape}')


class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        # 3개의 Layer 사용 (input = 8, output = 1로 고정, 중간 layer의 값은 상관없음)
        self.l1 = nn.Linear(8, 6)
        self.l2 = nn.Linear(6, 4)
        self.l3 = nn.Linear(4, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # x -> l1 -> l2 -> l3 -> y_pred
        out1 = self.sigmoid(self.l1(x))
        out2 = self.sigmoid(self.l2(out1))
        y_pred = self.sigmoid(self.l3(out2))
        return y_pred


# our model
model = Model()

# loss & optimizer
criterion = nn.BCELoss(reduction='mean') # BCELoss : 결과값이 0 or 1
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Training loop
for epoch in range(100):
    y_pred = model(x_data)

    # Compute and print loss
    loss = criterion(y_pred, y_data)
    print(f'Epoch: {epoch + 1}/100 | Loss: {loss.item():.4f}')

    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# X's shape: torch.Size([759, 8]) | Y's shape: torch.Size([759, 1])
# Epoch: 1/100 | Loss: 0.7083
# Epoch: 2/100 | Loss: 0.7014
# Epoch: 3/100 | Loss: 0.6953
# Epoch: 4/100 | Loss: 0.6898
# Epoch: 5/100 | Loss: 0.6850
# Epoch: 6/100 | Loss: 0.6806
# Epoch: 7/100 | Loss: 0.6768
# Epoch: 8/100 | Loss: 0.6734
# Epoch: 9/100 | Loss: 0.6703
# Epoch: 10/100 | Loss: 0.6676
# Epoch: 11/100 | Loss: 0.6652
# Epoch: 12/100 | Loss: 0.6630
# Epoch: 13/100 | Loss: 0.6611
# Epoch: 14/100 | Loss: 0.6594
# Epoch: 15/100 | Loss: 0.6579
# Epoch: 16/100 | Loss: 0.6565
# Epoch: 17/100 | Loss: 0.6553
# Epoch: 18/100 | Loss: 0.6542
# Epoch: 19/100 | Loss: 0.6533
# Epoch: 20/100 | Loss: 0.6524
# Epoch: 21/100 | Loss: 0.6516
# Epoch: 22/100 | Loss: 0.6510
# Epoch: 23/100 | Loss: 0.6504
# Epoch: 24/100 | Loss: 0.6498
# Epoch: 25/100 | Loss: 0.6493
# Epoch: 26/100 | Loss: 0.6489
# Epoch: 27/100 | Loss: 0.6485
# Epoch: 28/100 | Loss: 0.6482
# Epoch: 29/100 | Loss: 0.6478
# Epoch: 30/100 | Loss: 0.6476
# ...
